# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/Users/noahpovis/Desktop/Buildweek22/Build Week 2 /Buildweek22.csv', mangle_dupe_cols=True)

# %%
df['Funding Type'].value_counts()
# Out:
# Seed            23858
# Series A         3236
# Funding Type       37
# Name: Funding Type, dtype: int64

# %%
df.shape
# Out:
# (27131, 19)

# %%
df.drop_duplicates(subset=['Organization Name','Funding Type'], inplace = True)

# %%
df.drop_duplicates(keep='first', inplace= True)

# %%
df.shape
# Out:
# (22837, 19)

# %%
df['Raised Series A'] = np.where(df['Organization Name'].duplicated(), 'Yes', 'No')

# %%
df.drop_duplicates(subset='Organization Name', keep='last', inplace= True)

# %%
NowPay = df[df['Organization Name'] == 'Vara']
NowPay
# Out:
#         Transaction Name                               Transaction Name URL  \
# 27128  Seed Round - Vara  https://www.crunchbase.com/funding_round/vara-...
#
#       Organization Name                              Organization Name URL  \
# 27128              Vara  https://www.crunchbase.com/organization/vara-2d19
#
#       Funding Type Money Raised Money Raised Currency  \
# 27128         Seed          NaN                   NaN
#
#       Money Raised Currency (in USD) Announced Date Organization Description  \
# 27128                            NaN     2020-06-01                      NaN
#
#       Organization Industries Organization Location Total Funding Amount  \
# 27128                     NaN                   NaN             B2B SaaS
#
#       Total Funding Amount Currency Total Funding Amount Currency (in USD)  \
# 27128                           NaN                                    NaN
#
#       Investor Names Number of Investors Lead Investors  Lead Investors  \
# ...

# %%
df.shape
# Out:
# (21877, 20)

# %%
df.isnull().sum()
# Out:
# Transaction Name                              0
# Transaction Name URL                          0
# Organization Name                             0
# Organization Name URL                         0
# Funding Type                                  0
# Money Raised                               7062
# Money Raised Currency                      7056
# Money Raised Currency (in USD)             7062
# Announced Date                                0
# Organization Description                   4950
# Organization Industries                    5006
# Organization Location                      4973
# Total Funding Amount                        332
# Total Funding Amount Currency              1130
# Total Funding Amount Currency (in USD)      823
# Investor Names                              259
# Number of Investors                       11558
# Lead Investors                             6297
#  Lead Investors                            7828
# Raised Series A                               0
# ...

# %%
import plotly.express as px

# %%
df.dtypes
# Out:
# Transaction Name                                  object
# Transaction Name URL                              object
# Organization Name                                 object
# Organization Name URL                             object
# Funding Type                                      object
# Money Raised                                      object
# Money Raised Currency                             object
# Money Raised Currency (in USD)                   float64
# Announced Date                            datetime64[ns]
# Total Funding Amount                              object
# Total Funding Amount Currency                     object
# Total Funding Amount Currency (in USD)            object
# Organization Description                          object
# Organization Industries                           object
# Organization Location                            float64
# Number of Investors                               object
# ...

# %%
df['Money Raised Currency (in USD)'] = pd.to_numeric(df['Money Raised Currency (in USD)'], errors='coerce')

# %%
df['Total Funding Amount Currency (in USD)'] = pd.to_numeric(df['Total Funding Amount Currency (in USD)'], errors='coerce')

# %%
df['Announced Date'] = pd.to_datetime(df['Announced Date'], errors='coerce')

# %%
df['Total Funding Amount Currency (in USD)'] = pd.to_numeric(df['Total Funding Amount Currency (in USD)'], errors='coerce')

# %%
df.rename(columns={'Total Funding Amount':'Organization Description',
                          'Total Funding Amount Currency':'Organization Industries',
                          'Total Funding Amount Currency (in USD)':'Organization Location',
                          'Organization Description':'Total Funding Amount',
                          'Organization Industries':'Total Funding Amount Currency',
                          'Organization Location':'Total Funding Amount Currency (in USD)',
                          'Investor Names':'Number of Investors',
                          'Number of Investors':'Investor Names'
                          }, 
                 inplace=True)

# %%
df = df[df['Funding Type'] != 'Series A'] # get rid of all the companies that have Series A funding under funding type

# %%
df.columns = ['Transaction Name','Transaction Name URL','Organization Name','Organization Name URL', 'Funding Type', 'Money Raised', 'Money Raised Currency','Money Raised Currency (in USD)',  'Announced Date', 'Total Funding Amount' , 'Total Funding Amount Currency', 'Total Funding Amount Currency (in USD)', 'Organization Description', 'Organization Industries', 'Organization Location', 'Number of Investors', 'Investor Names','Lead Investor Number','Lead Investors','Raised Series A']

# %%
b = df[df['Raised Series A'] == 'Yes'] #number of startups that raised series A after seed round 
b
# Out:
#                              Transaction Name  \
# 3242     Seed Round - Clever Care Health Plan
# 3244                     Seed Round - The Org
# 3246              Seed Round - Big Sky Health
# 3250                       Seed Round - SeeQC
# 3253               Seed Round - Tugboat Logic
# ...                                       ...
# 25995                     Seed Round - Mr.Zoo
# 26012                     Seed Round - Agicap
# 26043                     Seed Round - NowPay
# 26255  Seed Round - Somai Pharmaceuticals Ltd
# 27128                       Seed Round - Vara
#
#                                     Transaction Name URL  \
# 3242   https://www.crunchbase.com/funding_round/cleve...
# 3244   https://www.crunchbase.com/funding_round/the-o...
# 3246   https://www.crunchbase.com/funding_round/big-s...
# 3250   https://www.crunchbase.com/funding_round/seeqc...
# 3253   https://www.crunchbase.com/funding_round/tugbo...
# ...                                                  ...
# ...

# %%
fig = px.scatter(df, x='Raised Series A', y='Money Raised Currency (in USD)')
fig.show()

# %%
df.shape
# Out:
# (19750, 20)

# %%
#swap number of investors and lead investors columns

# %%
pip install squarify #install for plotting
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install nltk
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install spacy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#NLP Environment setup 
from collections import Counter 

#Plotting 
import squarify
import matplotlib.pyplot as plt 
import seaborn as sns 

#NLP Libraries 
import re
from nltk.stem import PorterStemmer
import spacy
from spacy.tokenizer import Tokenizer

# %%
#make all lowercase 
df['Organization Description'] = df['Organization Description'].apply(lambda x: x.lower())

# %%
#convert column to str 
df['Organization Industries'].astype(str)
# Out:
# 940                          Total Funding Amount Currency
# 3239                         Financial Services, Insurance
# 3240     Artificial Intelligence, Consulting, Content, ...
# 3241                      Biotechnology, Food and Beverage
# 3242              Health Care, Health Insurance, Insurance
#                                ...
# 27126                                          Hospitality
# 27127    Artificial Intelligence, Computer, Industrial ...
# 27128                                                  nan
# 27129                          Biotechnology, Life Science
# 27130                                          Health Care
# Name: Organization Industries, Length: 19750, dtype: object

# %%
#make all lowercase
df['Organization Industries'] = df['Organization Industries'].str.lower()

# %%
df.sample(5)
# Out:
#                        Transaction Name  \
# 13453               Seed Round - Portis
# 4675   Seed Round - Perceptual Robotics
# 4056       Seed Round - Click Materials
# 15367         Seed Round - Kakaxi, Inc.
# 16419             Seed Round - Pop Game
#
#                                     Transaction Name URL    Organization Name  \
# 13453  https://www.crunchbase.com/funding_round/porti...               Portis
# 4675   https://www.crunchbase.com/funding_round/perce...  Perceptual Robotics
# 4056   https://www.crunchbase.com/funding_round/click...      Click Materials
# 15367  https://www.crunchbase.com/funding_round/kakax...         Kakaxi, Inc.
# 16419  https://www.crunchbase.com/funding_round/pop-g...             Pop Game
#
#                                    Organization Name URL Funding Type  \
# 13453     https://www.crunchbase.com/organization/portis         Seed
# 4675   https://www.crunchbase.com/organization/percep...         Seed
# ...

# %%
#finish lowercasing everything
